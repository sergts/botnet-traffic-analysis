# %%
# !ls
# Out:
# Anomaly_detection.ipynb             Danmini_Doorbell
# Botnet_traffic_classification.ipynb

# %%
import pandas as pd
import numpy as np
from scipy import stats
import tensorflow as tf
import pickle
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import scale
from keras.models import Model, load_model, Sequential
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard

# %%
df_bening = pd.read_csv('Danmini_Doorbell/bengin_traffic.csv')

# %%
df_bening.shape
# Out:
# (40395, 115)

# %%
df_bening = (df_bening - df_bening.mean()) / df_bening.std()

# %%
x_train, x_opt, x_test = np.split(df_bening, [int((1/3)*len(df_bening)), int((2/3)*len(df_bening))])

# %%
print(x_train.shape)
print(x_opt.shape)
print(x_test.shape)
# Out:
# (13465, 115)
# (13465, 115)
# (13465, 115)

# %%
nb_epoch = 800
input_dim = x_train.shape[1]
learning_rate = 0.012

autoencoder = Sequential()
autoencoder.add(Dense(int(0.75 * input_dim), input_dim=input_dim))
autoencoder.add(Dense(int(0.5 * input_dim)))
autoencoder.add(Dense(int(0.33 * input_dim)))
autoencoder.add(Dense(int(0.25 * input_dim)))
autoencoder.add(Dense(int(0.33 * input_dim)))
autoencoder.add(Dense(int(0.5 * input_dim)))
autoencoder.add(Dense(int(0.75 * input_dim)))
autoencoder.add(Dense(input_dim))

# %%
autoencoder.compile(loss='mean_squared_error',
                    optimizer='sgd')

cp = ModelCheckpoint(filepath="autoencoder_traffic.h5",
                               save_best_only=True,
                               verbose=0)

tb = TensorBoard(log_dir='./logs',
                histogram_freq=0,
                write_graph=True,
                write_images=True)

history = autoencoder.fit(x_train, x_train,
                    epochs=nb_epoch,
                    validation_data=(x_opt, x_opt),
                    verbose=1,
                    callbacks=[cp, tb]).history
# Out:
# Train on 13465 samples, validate on 13465 samples
# Epoch 1/800
# 13465/13465 [==============================] - 1s 71us/step - loss: 0.8379 - val_loss: 0.4705
# Epoch 2/800
# 13465/13465 [==============================] - 1s 55us/step - loss: 0.5382 - val_loss: 1.3549
# Epoch 3/800
# 13465/13465 [==============================] - 1s 55us/step - loss: 0.6233 - val_loss: 0.6183
# Epoch 4/800
# 13465/13465 [==============================] - 1s 56us/step - loss: 0.4646 - val_loss: 0.7244
# Epoch 5/800
# 13465/13465 [==============================] - 1s 55us/step - loss: 0.5193 - val_loss: 0.2569
# Epoch 6/800
# 13465/13465 [==============================] - 1s 56us/step - loss: 0.3737 - val_loss: 0.2044
# Epoch 7/800
# 13465/13465 [==============================] - 1s 55us/step - loss: 0.3581 - val_loss: 0.2533
# Epoch 8/800
# 13465/13465 [==============================] - 1s 56us/step - loss: 0.4101 - val_loss: 0.2869
# Epoch 9/800
# ...
